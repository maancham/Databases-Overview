# %%
# !pip install elasticsearch
# Out:
# Requirement already satisfied: elasticsearch in c:\users\hoomo\miniconda3\lib\site-packages (7.12.0)
# Requirement already satisfied: urllib3<2,>=1.21.1 in c:\users\hoomo\miniconda3\lib\site-packages (from elasticsearch) (1.25.8)
# Requirement already satisfied: certifi in c:\users\hoomo\miniconda3\lib\site-packages (from elasticsearch) (2020.6.20)
# WARNING: You are using pip version 20.2.3; however, version 21.1.1 is available.
# You should consider upgrading via the 'c:\users\hoomo\miniconda3\python.exe -m pip install --upgrade pip' command.

# %%
import time
from elasticsearch import Elasticsearch
import requests
import logging
import sys
import re

# %%
url = 'https://sahamyab.com/guest/twiter/list?v=0.1'
total = 1000
api_sleep = 1

# %%
def connect_elasticsearch():
    _es = None
    _es = Elasticsearch([{'host': 'localhost', 'port': 9200}])
    if _es.ping():
        print('Connected')
    else:
        print('Failed!')
    return _es
es = connect_elasticsearch()
# Out:
# Connected

# %%
def find_hashtags(text):
    return re.findall(r"#(\w+)", text)

# %%
def store_record(elastic_object, index_name, record):
    try:
        outcome = elastic_object.index(index=index_name, doc_type='twitter', body=record)
    except Exception as ex:
        print('Error in indexing data')
        print(str(ex))

# %%
res = 0
while res < total:
    response = requests.request('GET', url, headers={'User-Agent': 'Chrome/61'})
    if response.status_code == requests.codes.ok:
        data = response.json()['items']
        for d in data:
            d['hashtags'] = find_hashtags(d['content'])
            store_record(elastic_object=es, index_name='twitter', record=d)
        res = es.search(index='twitter', body={'query':{'match_all':{}}})['hits']['total']['value']
    else:
        print("Response code error: " + str(response.status_code))
    print('Fetched and inserted {} tweets so far'.format(res))
    print('Waiting for {} seconds...'.format(api_sleep))
    time.sleep(api_sleep)
# Out:
# c:\users\hoomo\miniconda3\lib\site-packages\elasticsearch\connection\base.py:200: ElasticsearchWarning: [types removal] Specifying types in document index requests is deprecated, use the typeless endpoints instead (/{index}/_doc/{id}, /{index}/_doc, or /{index}/_create/{id}).
#   warnings.warn(message, category=ElasticsearchWarning)
# Fetched and inserted 14 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 31 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 34 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 44 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 54 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 64 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 74 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 84 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 94 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 104 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 114 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 124 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 134 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 144 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 155 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 164 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 174 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 187 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 194 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 204 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 215 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 224 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 236 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 244 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 254 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 264 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 274 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 288 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 294 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 304 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 322 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 324 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 334 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 352 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 354 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 364 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 377 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 384 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 394 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 412 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 414 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 424 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 436 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 444 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 454 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 464 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 474 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 484 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 497 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 504 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 514 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 524 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 534 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 544 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 554 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 567 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 574 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 584 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 594 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 604 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 614 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 624 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 634 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 644 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 654 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 664 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 674 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 689 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 694 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 711 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 714 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 724 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 734 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 744 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 754 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 764 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 774 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 784 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 794 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 804 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 814 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 824 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 834 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 844 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 854 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 864 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 874 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 887 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 894 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 904 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 914 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 928 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 934 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 944 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 954 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 964 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 974 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 984 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 995 tweets so far
# Waiting for 1 seconds...
# Fetched and inserted 1004 tweets so far
# Waiting for 1 seconds...
